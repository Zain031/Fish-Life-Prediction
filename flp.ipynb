# %% [markdown]
# # Fish Life Prediction

# %% [markdown]
# Predicting if fish can life in stated water environment.

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import json
import sys

#Disable Warning
import warnings
warnings.filterwarnings('ignore')

# Outlier Handling
from feature_engine.outliers import Winsorizer

# Stats Analysis
from scipy.stats import f_oneway

# Machine Learning
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier

# Machine Learning Pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Machine Learning Evaluation
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# # Data Loading

# %%
database = pd.read_csv('Realtime-env2.csv')
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74796 entries, 0 to 74795
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             74758 non-null  object
#  1   Time             74707 non-null  object
#  2   NITRATE(PPM)     74758 non-null  float64
#  3   PH               74758 non-null  float64
#  4   AMMONIA(mg/l)    74758 non-null  float64
#  5   TEMP             74758 non-null  float64
#  6   DO               74758 non-null  float64
#  7   TURBIDITY        74758 non-null  float64
#  8   MANGANESE(mg/l)  74758 non-null  float64
#  9   pressure         74758 non-null  float64
#  10  tempC            74758 non-null  float64
#  11  humidity         74758 non-null  float64
#  12  windspeedKmph    74758 non-null  float64
#  13  label            74758 non-null  float64
# dtypes: float64(12), object(2)
# memory usage: 8.0+ MB

# %%
database.head()
# Out:
#          Date      Time  NITRATE(PPM)   PH  AMMONIA(mg/l)   TEMP   DO  \
# 0  01-02-2022  08:00:00         112.1  7.7          0.002  24.35  1.9
# 1  01-02-2022  08:20:00         119.8  7.6          0.088  24.30  0.8
# 2  01-02-2022  08:40:00         127.4  8.5          0.029  24.28  2.6
# 3  01-02-2022  09:00:00         105.0  7.5          0.060  24.25  2.9
# 4  01-02-2022  09:20:00         121.1  7.4          0.001  24.10  1.3
#
#    TURBIDITY  MANGANESE(mg/l)  pressure  tempC  humidity  windspeedKmph  label
# 0       21.3             2.01    1012.0   27.0      21.0            4.0    0.0
# 1       31.0             1.00    1012.0   30.0      19.0            4.0    0.0
# 2       27.4             2.45    1012.0   33.0      16.0            4.0    0.0
# 3       21.9             1.83    1011.0   37.0      13.0            4.0    0.0
# 4       22.7             1.69    1010.0   37.0      12.0            4.0    0.0

# %%
database.tail()
# Out:
#       Date Time  NITRATE(PPM)  PH  AMMONIA(mg/l)  TEMP  DO  TURBIDITY  \
# 74791  NaN  NaN           NaN NaN            NaN   NaN NaN        NaN
# 74792  NaN  NaN           NaN NaN            NaN   NaN NaN        NaN
# 74793  NaN  NaN           NaN NaN            NaN   NaN NaN        NaN
# 74794  NaN  NaN           NaN NaN            NaN   NaN NaN        NaN
# 74795  NaN  NaN           NaN NaN            NaN   NaN NaN        NaN
#
#        MANGANESE(mg/l)  pressure  tempC  humidity  windspeedKmph  label
# 74791              NaN       NaN    NaN       NaN            NaN    NaN
# 74792              NaN       NaN    NaN       NaN            NaN    NaN
# 74793              NaN       NaN    NaN       NaN            NaN    NaN
# 74794              NaN       NaN    NaN       NaN            NaN    NaN
# 74795              NaN       NaN    NaN       NaN            NaN    NaN

# %% [markdown]
# Insight: Data Has 13 column with 2 object type and 11 numeric type.

# %% [markdown]
# ### Domain Knowledge

# %% [markdown]
# In this Dataset, Date and Time doesn't have use because we using classification model rather than time series, so it's save to drop it.

# %%
# Drop Date and Time Column
database.drop(columns=['Date','Time'],inplace=True)
database.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74796 entries, 0 to 74795
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   NITRATE(PPM)     74758 non-null  float64
#  1   PH               74758 non-null  float64
#  2   AMMONIA(mg/l)    74758 non-null  float64
#  3   TEMP             74758 non-null  float64
#  4   DO               74758 non-null  float64
#  5   TURBIDITY        74758 non-null  float64
#  6   MANGANESE(mg/l)  74758 non-null  float64
#  7   pressure         74758 non-null  float64
#  8   tempC            74758 non-null  float64
#  9   humidity         74758 non-null  float64
#  10  windspeedKmph    74758 non-null  float64
#  11  label            74758 non-null  float64
# dtypes: float64(12)
# memory usage: 6.8 MB

# %% [markdown]
# # Exploration Data Analysis

# %% [markdown]
# ### See Duplicate Data

# %%
database.duplicated().sum()
# Out:
# 37

# %% [markdown]
# Insight: There's Duplicated Data

# %% [markdown]
# ### See Which Columns That Has Duplicated Data

# %%
database.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 74791     True
# 74792     True
# 74793     True
# 74794     True
# 74795     True
# Length: 74796, dtype: bool

# %%
database.loc[74791:74795,:]
# Out:
#        NITRATE(PPM)  PH  AMMONIA(mg/l)  TEMP  DO  TURBIDITY  MANGANESE(mg/l)  \
# 74791           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74792           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74793           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74794           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74795           NaN NaN            NaN   NaN NaN        NaN              NaN
#
#        pressure  tempC  humidity  windspeedKmph  label
# 74791       NaN    NaN       NaN            NaN    NaN
# 74792       NaN    NaN       NaN            NaN    NaN
# 74793       NaN    NaN       NaN            NaN    NaN
# 74794       NaN    NaN       NaN            NaN    NaN
# 74795       NaN    NaN       NaN            NaN    NaN

# %% [markdown]
# Insight: Duplicated Data Are NaN Value, so it's safe to ignore the duplicate because we'll handle the NaN value.

# %% [markdown]
# ### See Cardinality of Data

# %%
database.nunique()
# Out:
# NITRATE(PPM)       53330
# PH                 46273
# AMMONIA(mg/l)      22217
# TEMP               51787
# DO                 53697
# TURBIDITY          49789
# MANGANESE(mg/l)    44486
# pressure              30
# tempC                 42
# humidity              98
# windspeedKmph         37
# label                  2
# dtype: int64

# %%
# Visualization
sns.barplot(database.nunique(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: All columns has large unique data with cardinality > 15

# %% [markdown]
# ### See Empty Data

# %%
database.isnull().sum()
# Out:
# NITRATE(PPM)       38
# PH                 38
# AMMONIA(mg/l)      38
# TEMP               38
# DO                 38
# TURBIDITY          38
# MANGANESE(mg/l)    38
# pressure           38
# tempC              38
# humidity           38
# windspeedKmph      38
# label              38
# dtype: int64

# %%
#Visualization
sns.barplot(orient='h',data=database.isnull().sum())
# Out:
# <Axes: >

# %% [markdown]
# Insight: All Column Have Empty value/Null Value with same size of empty data.

# %% [markdown]
# ### See Correlation Each of Column From Empty Data

# %%
sns.heatmap(data=database.isnull().corr(method='kendall'),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Insight: All empty data From Column have strong correlation each other.

# %% [markdown]
# ### See Occurence Which Data that has Null Value

# %%
# Assuming 'database' is your DataFrame
# Use .isnull() to create a DataFrame of True/False values where True indicates NaN
nan_locations = database.isnull()

# Use .any(axis=1) to check if any NaN value is present in each row
rows_with_null = nan_locations.any(axis=1)

# Display the rows with null values
rows_with_null_df = database[rows_with_null]
print(rows_with_null_df[:10])
# Out:
#        NITRATE(PPM)  PH  AMMONIA(mg/l)  TEMP  DO  TURBIDITY  MANGANESE(mg/l)  \
# 74758           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74759           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74760           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74761           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74762           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74763           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74764           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74765           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74766           NaN NaN            NaN   NaN NaN        NaN              NaN
# 74767           NaN NaN            NaN   NaN NaN        NaN              NaN
#
#        pressure  tempC  humidity  windspeedKmph  label
# 74758       NaN    NaN       NaN            NaN    NaN
# 74759       NaN    NaN       NaN            NaN    NaN
# 74760       NaN    NaN       NaN            NaN    NaN
# 74761       NaN    NaN       NaN            NaN    NaN
# 74762       NaN    NaN       NaN            NaN    NaN
# 74763       NaN    NaN       NaN            NaN    NaN
# 74764       NaN    NaN       NaN            NaN    NaN
# 74765       NaN    NaN       NaN            NaN    NaN
# 74766       NaN    NaN       NaN            NaN    NaN
# 74767       NaN    NaN       NaN            NaN    NaN

# %% [markdown]
# Insight: NaN data have same occurence on same row on all Column, so it's save to drop it latter on Feature Engineering.

# %% [markdown]
# ### See the Means Of Data

# %%
database.mean()
# Out:
# NITRATE(PPM)         38.699076
# PH                    6.542758
# AMMONIA(mg/l)         0.096194
# TEMP                 27.226410
# DO                   10.762849
# TURBIDITY            31.594800
# MANGANESE(mg/l)       0.981192
# pressure           1008.148051
# tempC                27.693250
# humidity             46.384681
# windspeedKmph         8.761310
# label                 0.732310
# dtype: float64

# %%
#Visualization
database.mean().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ### See Skewness of Data

# %%
database.skew()
# Out:
# NITRATE(PPM)       1.554859
# PH                 0.379243
# AMMONIA(mg/l)      5.215232
# TEMP               0.591164
# DO                 0.602759
# TURBIDITY          1.013689
# MANGANESE(mg/l)    1.776782
# pressure          -0.009938
# tempC              0.221178
# humidity           0.381365
# windspeedKmph      0.891597
# label             -1.049402
# dtype: float64

# %%
# Visualization
sns.barplot(database.skew(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: PH tempC and humidity has Normal Distribution of Data, while other than that has Skewwed Distribution of Data.

# %% [markdown]
# ### See Kurtosis of Data

# %%
database.kurtosis()
# Out:
# NITRATE(PPM)        1.486333
# PH                 -0.692156
# AMMONIA(mg/l)      32.704746
# TEMP                0.385738
# DO                 -0.504282
# TURBIDITY           1.138160
# MANGANESE(mg/l)     2.161953
# pressure           -1.045701
# tempC              -0.332113
# humidity           -1.061804
# windspeedKmph       1.204482
# label              -0.898779
# dtype: float64

# %%
# Visualization
sns.barplot(database.kurtosis(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: Majority of data has large outlier with kurtosis not equal to 0.

# %% [markdown]
# ### See Correlation of Each Data

# %%
plt.figure(figsize=(10,10))
sns.heatmap(database.corr(method='kendall'),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Insight: NITRATE(PPM), PH, AMMONIA(mg/l), TEMP, TURBIDITY, MANGANESE(mg/l) are column that have high correlation towards data with correlation > 10%.

# %%
feature = ['NITRATE(PPM)', 'PH', 'AMMONIA(mg/l)', 'TEMP', 'TURBIDITY', 'MANGANESE(mg/l)']

# %% [markdown]
# ### See Correlation of Each Feature

# %%
plt.figure(figsize=(10,10))
sns.heatmap(database[feature].corr(method='kendall'),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Insight:
# - TEMP and MANGANESE(mg/l) have small correlation of each other.
# - TURBIDITY and PH have small correlation of each other.
# - PH and Nitrate have small correlation of each other.

# %% [markdown]
# ### See Correlation From Feature to Target

# %%
sns.heatmap(database[feature+['label']].corr(method='kendall'),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Insight:
# Correlation difference between feature that has correlation with each other:
# - TEMP < MANGANESE(mg/l)
# - TURBIDITY > PH
# - PH < NITRATE(PPM)
#
# By this, the feature that being used based of how large the correlation to target are MANGANESE(mg/l), TURBIDITY, NITRATE(PPM)

# %%
feature = ['MANGANESE(mg/l)', 'TURBIDITY', 'NITRATE(PPM)']

# %% [markdown]
# That's small version of it, But for sake of accuracy, We take all of feature and drop duplicated columns.

# %%
feature = database.columns.tolist()
feature.remove('label')
feature
# Out:
# ['NITRATE(PPM)',
#  'PH',
#  'AMMONIA(mg/l)',
#  'TEMP',
#  'DO',
#  'TURBIDITY',
#  'MANGANESE(mg/l)',
#  'pressure',
#  'tempC',
#  'humidity',
#  'windspeedKmph']

# %% [markdown]
# ### See Feature that are duplicate

# %%
for i in feature:
    count = 0
    stored_duplicate=[]
    for j in feature:
        if i.lower() in j.lower():
            stored_duplicate.append(j)
    if len(stored_duplicate)>1:
        print(f"Column that duplicated each other: {stored_duplicate}")
# Out:
# Column that duplicated each other: ['PH', 'windspeedKmph']
# Column that duplicated each other: ['TEMP', 'tempC']

# %% [markdown]
# Insight:
# - PH and windspeedKmph are not duplicates because it has different purpose on each other.
# - TEMP and tempC are duplicates because it has same purpose based on it's name

# %% [markdown]
# ### See which of it has strong correlation to target

# %%
sns.heatmap(database[['TEMP','tempC']+['label']].corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Insight: TEMP are have strong correlation than tempC, so it's safe to drop it

# %%
feature.remove('tempC')
feature
# Out:
# ['NITRATE(PPM)',
#  'PH',
#  'AMMONIA(mg/l)',
#  'TEMP',
#  'DO',
#  'TURBIDITY',
#  'MANGANESE(mg/l)',
#  'pressure',
#  'humidity',
#  'windspeedKmph']

# %% [markdown]
# ### See Skewness of Feature

# %%
database[feature].skew()
# Out:
# NITRATE(PPM)       1.554859
# PH                 0.379243
# AMMONIA(mg/l)      5.215232
# TEMP               0.591164
# DO                 0.602759
# TURBIDITY          1.013689
# MANGANESE(mg/l)    1.776782
# pressure          -0.009938
# humidity           0.381365
# windspeedKmph      0.891597
# dtype: float64

# %%
# Visualization
sns.barplot(database[feature].skew(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: Feature has Skewwed distribution with skewness > 0.5

# %% [markdown]
# ### See Kurtosis of Feature

# %%
database[feature].kurtosis()
# Out:
# NITRATE(PPM)        1.486333
# PH                 -0.692156
# AMMONIA(mg/l)      32.704746
# TEMP                0.385738
# DO                 -0.504282
# TURBIDITY           1.138160
# MANGANESE(mg/l)     2.161953
# pressure           -1.045701
# humidity           -1.061804
# windspeedKmph       1.204482
# dtype: float64

# %%
#Visualization
sns.barplot(database[feature].skew(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: Feature has large outlier with kurtosis >= 1

# %% [markdown]
# ### See Cardinality of Feature

# %%
database[feature].nunique()
# Out:
# NITRATE(PPM)       53330
# PH                 46273
# AMMONIA(mg/l)      22217
# TEMP               51787
# DO                 53697
# TURBIDITY          49789
# MANGANESE(mg/l)    44486
# pressure              30
# humidity              98
# windspeedKmph         37
# dtype: int64

# %%
#Visualization
sns.barplot(database[feature].nunique(),orient='h')
# Out:
# <Axes: >

# %% [markdown]
# Insight: Feature have High Cardinality, meaning Feature are Numeric Data

# %% [markdown]
# ## EDA Conclusion
# - All Data has high cardinality except label, **So label are categorical and outlier doesn't need to be handled**
# - All Data have number type, **so all feature will be scalled**
# - The feature are **MANGANESE, TURBIDITY, NITRATE(PPM)** columns
# - The target are **label** column
# - Feature Have High Cardinality, **so feature are numeric**
# - Feature has Large Outlier, **so outlier need to be handled**
# - Feature has skewwed Data, **So Scaling technique that be used are MinMaxScaller and Outlier Handling that'll be used are IQR capping method**
# - Empty Data are in same row, **so it's safe to drop the row that has Empty Data**

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Handling Missing Value

# %%
database.dropna(inplace=True)
database.isnull().sum()
# Out:
# NITRATE(PPM)       0
# PH                 0
# AMMONIA(mg/l)      0
# TEMP               0
# DO                 0
# TURBIDITY          0
# MANGANESE(mg/l)    0
# pressure           0
# tempC              0
# humidity           0
# windspeedKmph      0
# label              0
# dtype: int64

# %% [markdown]
# Insight: Missing Value Has been dropped

# %% [markdown]
# ### Data Splitting

# %%
X,y = database.drop(columns=['label']), database['label']
[X.shape, y.shape]
# Out:
# [(74758, 11), (74758,)]

# %% [markdown]
# Insight: Data Has Been Splitted with X as feature and y as Target.

# %% [markdown]
# ### Feature Selection

# %% [markdown]
# Based on EDA, feature has been selected and stored on feature variable.

# %%
X=X[feature]
X.columns
# Out:
# Index(['NITRATE(PPM)', 'PH', 'AMMONIA(mg/l)', 'TEMP', 'DO', 'TURBIDITY',
#        'MANGANESE(mg/l)', 'pressure', 'humidity', 'windspeedKmph'],
#       dtype='object')

# %% [markdown]
# ### Train Test Split

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0,stratify=y)

# %% [markdown]
# Insight: Data Has been splitted to train and test

# %% [markdown]
# ### Handling Outlier

# %%
# Handling Outlier
win_skew = Winsorizer(capping_method='iqr',fold=1.5,tail='both',variables=X.columns.to_list())

win_skew.fit(X_train)
X_train = win_skew.transform(X_train)
X_test = win_skew.transform(X_test)

# %% [markdown]
# Insight: Outlier has been handled

# %% [markdown]
# # Model Definition

# %%
# Model Definition
model_base = {
    'logic':LogisticRegression(),    
    'knn':KNeighborsClassifier(),
    'svc':SVC(),
    'decision':DecisionTreeClassifier()
}
model={}
for key,modeling in model_base.items():
    model[key]=Pipeline([('scaler',RobustScaler()),('model',modeling)])
model
# Out:
# {'logic': Pipeline(steps=[('scaler', RobustScaler()), ('model', LogisticRegression())]),
#  'knn': Pipeline(steps=[('scaler', RobustScaler()), ('model', KNeighborsClassifier())]),
#  'svc': Pipeline(steps=[('scaler', RobustScaler()), ('model', SVC())]),
#  'decision': Pipeline(steps=[('scaler', RobustScaler()),
#                  ('model', DecisionTreeClassifier())])}

# %% [markdown]
# Insight: Model Has Been Defined

# %%
# Hyperparameter definition
hyperparam = {
    'logic': {
        'model__C': [0.01, 0.1, 1.0],
        'model__penalty': ['l1', 'l2', 'elasticnet', None],
        'model__solver': ['liblinear', 'lbfgs', 'sag','newton-cg'],
        'model__max_iter': [100, 200]
    },
    'knn': {
        'model__n_neighbors': [3, 5, 7, 9, 11],
        'model__p': [1, 2],
        'model__algorithm': ['auto', 'ball_tree', 'kd_tree']
    },
    'svc': {
        'model__C': [0.01, 0.1, 1.0],
        'model__kernel': ['rbf', 'linear', 'poly', 'sigmoid'],
    },
    'decision':{
        'model__criterion': ['gini', 'entropy'],
        'model__splitter': ['best', 'random'],
        'model__max_depth': [None, 10, 20, 30],  # Adjust based on your dataset and complexity requirements
        'model__min_samples_split': [2, 5, 10],
        'model__min_samples_leaf': [1, 2, 4],
        'model__max_features': ['auto', 'sqrt', 'log2', None]
    }
}

# %% [markdown]
# Insight: Hyperparameter Has Been Defined

# %% [markdown]
# # Model Training

# %% [markdown]
# ### Without Tunning

# %%
### Without Tunning
wot_model = {}
for key, modeling in model.items():
    wot_model[key] = modeling.fit(X_train,y_train)
wot_model
# Out:
# {'logic': Pipeline(steps=[('scaler', RobustScaler()), ('model', LogisticRegression())]),
#  'knn': Pipeline(steps=[('scaler', RobustScaler()), ('model', KNeighborsClassifier())]),
#  'svc': Pipeline(steps=[('scaler', RobustScaler()), ('model', SVC())]),
#  'decision': Pipeline(steps=[('scaler', RobustScaler()),
#                  ('model', DecisionTreeClassifier())])}

# %% [markdown]
# Insight: Model Has Been Train without tunning.

# %% [markdown]
# ### With Tunning

# %%
### With Tunning
wt_model = {}
for key, modeling in model.items():
    try:
        print(key)
        grid = RandomizedSearchCV(modeling,hyperparam[key],cv=5,n_jobs=-1,random_state=0)
        grid.fit(X_train,y_train)
        wt_model[key] = grid.best_estimator_
    except:
        grid = RandomizedSearchCV(modeling,hyperparam[key],cv=5,n_jobs=-1,random_state=0)
        grid.fit(X_train,y_train)
        wt_model[key] = grid.best_estimator_
wt_model
# Out:
# logic
# knn
# svc
# decision
# {'logic': Pipeline(steps=[('scaler', RobustScaler()),
#                  ('model',
#                   LogisticRegression(C=0.1, max_iter=200, solver='newton-cg'))]),
#  'knn': Pipeline(steps=[('scaler', RobustScaler()),
#                  ('model',
#                   KNeighborsClassifier(algorithm='kd_tree', n_neighbors=11,
#                                        p=1))]),
#  'svc': Pipeline(steps=[('scaler', RobustScaler()), ('model', SVC())]),
#  'decision': Pipeline(steps=[('scaler', RobustScaler()),
#                  ('model',
#                   DecisionTreeClassifier(criterion='entropy', max_depth=10))])}

# %% [markdown]
# Insight: Model Has Been Trained with tunning

# %% [markdown]
# # Model Evaluation

# %%
def right_percent(feature,target,model_test):
    result={}
    if len(model_test)>1:
        for key,modeling in model_test.items():
            predict = modeling.predict(feature)
            result[key] = f'{round((target == predict).mean()*100,2)}%'
            print(f'{key} : {result[key]}')
    else:
        predict = modeling.predict(feature)
        result = f'{round((target == predict).mean()*100,2)}%'
        print(f'model: {result}')
    return result    

def full_eva(feature,target,model_train):
    if len(model_train)>1:
        for key, modeling in model_train.items():
            predict = modeling.predict(feature)
            print("="*20,key,"="*20)
            print(classification_report(target,predict))
    else:
        predict = model_train.predict(feature)
        print("="*20,key,"="*20)
        print(classification_report(target,predict))

def conf_matrix_show(feature,target,model_train):
    if len(model_train)>1:
        for key, modeling in model_train.items():
            prediction = modeling.predict(feature)
            cm = confusion_matrix(target,prediction)
            disp = ConfusionMatrixDisplay(cm)
            disp.plot()
            plt.title(key)
            plt.show()
    else:
        prediction = model_train.predict(feature)
        cm = confusion_matrix(target,prediction)
        disp = ConfusionMatrixDisplay(cm)
        disp.plot()
        plt.title(key)
        plt.show()

# %% [markdown]
# ### Match Percentage

# %% [markdown]
# #### Without Tunning

# %%
print('='*20,'Train','='*20)
right_percent(X_train,y_train,wot_model)
print('='*20,'Test','='*20)
right_percent(X_test,y_test,wot_model)
# Out:
# ==================== Train ====================
# logic : 97.15%
# knn : 98.18%
# svc : 98.31%
# decision : 100.0%
# ==================== Test ====================
# logic : 97.12%
# knn : 97.42%
# svc : 98.09%
# decision : 96.92%
# {'logic': '97.12%', 'knn': '97.42%', 'svc': '98.09%', 'decision': '96.92%'}

# %% [markdown]
# Insight:
# - All model have high percentage, but decision tree model are overfit when predict train data.
# - Highest and Consistent percentage on train and test are SVC model with match percentage 98% on train and test

# %% [markdown]
# #### With Tunning

# %%
print('='*20,'Train','='*20)
right_percent(X_train,y_train,wt_model)
print('='*20,'Test','='*20)
right_percent(X_test,y_test,wt_model)
# print('='*20,'Real Data Test','='*20)
# right_percent(X,y,wt_model)
# Out:
# ==================== Train ====================
# logic : 97.14%
# knn : 97.83%
# svc : 98.31%
# decision : 98.68%
# ==================== Test ====================
# logic : 97.15%
# knn : 97.61%
# svc : 98.09%
# decision : 97.1%
# {'logic': '97.15%', 'knn': '97.61%', 'svc': '98.09%', 'decision': '97.1%'}

# %% [markdown]
# Insight:
# - All model have high percentage
# - Highest and Consistent percentage on train and test are SVC model with match percentage 98% on train and test

# %% [markdown]
# ### Classification Report

# %% [markdown]
# #### Without Tunning

# %%
print('='*20,'Train','='*20)
full_eva(X_train,y_train,wot_model)
print('='*20,'Test','='*20)
full_eva(X_test,y_test,wot_model)
# Out:
# ==================== Train ====================
# ==================== logic ====================
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     14008
#          1.0       0.98      0.98      0.98     38322
#
#     accuracy                           0.97     52330
#    macro avg       0.96      0.96      0.96     52330
# weighted avg       0.97      0.97      0.97     52330
#
# ==================== knn ====================
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     14008
#          1.0       0.99      0.98      0.99     38322
#
#     accuracy                           0.98     52330
#    macro avg       0.97      0.98      0.98     52330
# weighted avg       0.98      0.98      0.98     52330
#
# ==================== svc ====================
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     14008
#          1.0       0.99      0.99      0.99     38322
#
#     accuracy                           0.98     52330
#    macro avg       0.98      0.98      0.98     52330
# weighted avg       0.98      0.98      0.98     52330
#
# ==================== decision ====================
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     14008
#          1.0       1.00      1.00      1.00     38322
#
#     accuracy                           1.00     52330
#    macro avg       1.00      1.00      1.00     52330
# weighted avg       1.00      1.00      1.00     52330
#
# ==================== Test ====================
# ==================== logic ====================
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95      6004
#          1.0       0.98      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.96      0.96     22428
# weighted avg       0.97      0.97      0.97     22428
#
# ==================== knn ====================
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.96      0.95      6004
#          1.0       0.99      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.97      0.97     22428
# weighted avg       0.97      0.97      0.97     22428
#
# ==================== svc ====================
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96      6004
#          1.0       0.99      0.98      0.99     16424
#
#     accuracy                           0.98     22428
#    macro avg       0.97      0.98      0.98     22428
# weighted avg       0.98      0.98      0.98     22428
#
# ==================== decision ====================
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.94      6004
#          1.0       0.98      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.96      0.96     22428
# weighted avg       0.97      0.97      0.97     22428

# %% [markdown]
# #### With Tunning

# %%
print('='*20,'Train','='*20)
full_eva(X_train,y_train,wt_model)
print('='*20,'Test','='*20)
full_eva(X_test,y_test,wt_model)
# Out:
# ==================== Train ====================
# ==================== logic ====================
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.95      0.95     14008
#          1.0       0.98      0.98      0.98     38322
#
#     accuracy                           0.97     52330
#    macro avg       0.96      0.96      0.96     52330
# weighted avg       0.97      0.97      0.97     52330
#
# ==================== knn ====================
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.98      0.96     14008
#          1.0       0.99      0.98      0.99     38322
#
#     accuracy                           0.98     52330
#    macro avg       0.97      0.98      0.97     52330
# weighted avg       0.98      0.98      0.98     52330
#
# ==================== svc ====================
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.98      0.97     14008
#          1.0       0.99      0.99      0.99     38322
#
#     accuracy                           0.98     52330
#    macro avg       0.98      0.98      0.98     52330
# weighted avg       0.98      0.98      0.98     52330
#
# ==================== decision ====================
#               precision    recall  f1-score   support
#
#          0.0       0.97      0.98      0.98     14008
#          1.0       0.99      0.99      0.99     38322
#
#     accuracy                           0.99     52330
#    macro avg       0.98      0.98      0.98     52330
# weighted avg       0.99      0.99      0.99     52330
#
# ==================== Test ====================
# ==================== logic ====================
#               precision    recall  f1-score   support
#
#          0.0       0.95      0.94      0.95      6004
#          1.0       0.98      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.96      0.96     22428
# weighted avg       0.97      0.97      0.97     22428
#
# ==================== knn ====================
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.97      0.96      6004
#          1.0       0.99      0.98      0.98     16424
#
#     accuracy                           0.98     22428
#    macro avg       0.96      0.98      0.97     22428
# weighted avg       0.98      0.98      0.98     22428
#
# ==================== svc ====================
#               precision    recall  f1-score   support
#
#          0.0       0.96      0.97      0.96      6004
#          1.0       0.99      0.98      0.99     16424
#
#     accuracy                           0.98     22428
#    macro avg       0.97      0.98      0.98     22428
# weighted avg       0.98      0.98      0.98     22428
#
# ==================== decision ====================
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95      6004
#          1.0       0.98      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.96      0.96     22428
# weighted avg       0.97      0.97      0.97     22428

# %% [markdown]
# ### Confusion Matrix

# %% [markdown]
# #### Without Tunning

# %%
print('='*20,'Train','='*20)
conf_matrix_show(X_train,y_train,wot_model)
print('='*20,'Test','='*20)
conf_matrix_show(X_test,y_test,wot_model)
# print('='*20,'Real Data Test','='*20)
# conf_matrix_show(X,y,wot_model)
# Out:
# ==================== Train ====================
# ==================== Test ====================

# %% [markdown]
# #### With Tunning

# %%
print('='*20,'Train','='*20)
conf_matrix_show(X_train,y_train,wt_model)
print('='*20,'Test','='*20)
conf_matrix_show(X_test,y_test,wt_model)
# print('='*20,'Real Data Test','='*20)
# conf_matrix_show(X,y,wt_model)
# Out:
# ==================== Train ====================
# ==================== Test ====================

# %% [markdown]
# ## Model Evaluation Conclusion

# %% [markdown]
# - In Train Test Percentage Evaluation, KNN after tunning are good because it have > 95% accuracy and highest f1-score
# - In Confusion Matrix Evaluation, Decision Tree Classifier after tunning are good because it have smallest False Positive and doesn't overfit unlike before Tunning
# - Decision Tree after tunning are model that'll be saved because it has smallest False Positive and it's most stable models

# %%
gbc = GridSearchCV(GradientBoostingClassifier())
gbc.fit(X_train,y)
# Out:
# GradientBoostingClassifier(learning_rate=0.001, n_estimators=500)

# %%
predict = gbc.predict(X_test)
dcf_predict = wt_model['decision'].predict(X_test)
print(classification_report(y_test,dcf_predict))
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.95      0.95      6004
#          1.0       0.98      0.98      0.98     16424
#
#     accuracy                           0.97     22428
#    macro avg       0.96      0.96      0.96     22428
# weighted avg       0.97      0.97      0.97     22428
#
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.73      0.84      6004
#          1.0       0.91      0.99      0.95     16424
#
#     accuracy                           0.92     22428
#    macro avg       0.94      0.86      0.89     22428
# weighted avg       0.93      0.92      0.92     22428

# %% [markdown]
# # Model Saving

# %%
# Feature Saving
json.dump(feature,open('feature.json','w'))
# Model Saving
joblib.dump(wt_model['decision'],'model.pkl')
# Out:
# ['model.pkl']

# %% [markdown]
# # Model Inference

# %%
model_test = joblib.load('model.pkl')

# %%
model_test.predict(X)
# Out:
# array([0., 1., 0., ..., 1., 1., 1.])

# %% [markdown]
# # Requirement Listing

# %%
import matplotlib
import sklearn
import feature_engine
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import json
req = f"""
      #python=={sys.version}
      numpy=={np.__version__}
      pandas=={pd.__version__}
      matplotlib=={matplotlib.__version__}
      seaborn=={sns.__version__}
      joblib=={joblib.__version__}
      scikit-learn=={sklearn.__version__}
      feature-engine=={feature_engine.__version__}
      """
with open('requirements.txt','w') as file:
      file.write(req)
